# %%
import ultralytics
ultralytics.checks()

# %%
from ultralytics import YOLO as yolo
from IPython.display import display, Image

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="sCoQ1oYiNNK5RxMwVs72")
project = rf.workspace("project-uyrxf").project("ppe_detection-v1x3l")
version = project.version(2)    
dataset = version.download("yolov11")

# %%
model=yolo("yolo11n.pt")
dataset_path = "../assets/dataset/PPE_Detection-2/data.yaml"
results = model.train(data=dataset_path, epochs=40, imgsz=640,device=0, name="yolo11n-safety-vests")

# %%
path_results = "runs/detect/yolo11n-safety-vests-3/"

# %%
Image(path_results + "BoxF1_curve.png")

# %%
Image(path_results + "BoxP_curve.png")

# %%
Image(path_results + "BoxR_curve.png")

# %%
Image(path_results + "BoxPR_curve.png")

# %%
Image(path_results + "confusion_matrix.png")

# %%
Image(path_results + "confusion_matrix_normalized.png")

# %%
Image(path_results + "labels.jpg")

# %%
Image(path_results + "results.png")

# %%
Image(path_results + "train_batch0.jpg")

# %%
Image(path_results + "val_batch0_labels.jpg")

# %%
Image(path_results + "val_batch0_pred.jpg")

# %%
modelbest = yolo(path_results + "weights/best.pt")
results_val = modelbest.val(data=dataset_path)

# %%
result_test= modelbest.predict(source="../assets/dataset/PPE_Detection-2/test/images", save=True, device=0, conf=0.25, name="yolo11n-safety-vests-test-results")

# %%
import glob
from IPython.display import Image as IPyImage, display
latest_folder = "runs/detect/yolo11n-safety-vests-test-results-2"
for img in glob.glob(f'{latest_folder}/*.jpg')[1:4]:
    display(IPyImage(filename=img, width=600))
    print("\n")
