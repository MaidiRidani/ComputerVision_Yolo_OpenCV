# %%
import requests
url = "https://drive.google.com/uc?id=1Xa1EJO_Uwv-qr0i72VK2TaQALz7X0EP1&confirm=t"
r=requests.get(url)
r.raise_for_status

with open(  "../assets/day2/image1.jpg","wb") as f:
    f.write(r.content)

# %%
url = "https://drive.google.com/uc?id=1l65gM2eQMhutLP9jpySZfaQIAB_OqO2j&confirm=t"
r = requests.get(url)
r.raise_for_status

with open("../assets/day2/video1.mp4","wb") as f:
    f.write(r.content)

# %%
import requests
url = "https://drive.google.com/uc?id=1l65gM2eQMhutLP9jpySZfaQIAB_OqO2j&confirm=t"
r=requests.get(url)
print(r.headers["Content-Type"])
with open(  "../assets/day2/video1.mp4","wb") as f:
    f.write(r.content)
# Out:
# video/mp4

# %%
from ultralytics import YOLO
model = YOLO("yolo11n.pt")
pathimage1 = "../assets/day2/image1.jpg"
result = model.predict(source=pathimage1, save=True, project="day2result")
# Out:
# image 1/1 /media/dani/WareHouseHDD1/GitHub/ComputerVision_Yolo_OpenCV/hands-on/../assets/day2/image1.jpg: 448x640 12 persons, 1 bus, 2 traffic lights, 3 backpacks, 1 handbag, 3.7ms
# Speed: 15.1ms preprocess, 3.7ms inference, 7.7ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /media/dani/WareHouseHDD1/GitHub/ComputerVision_Yolo_OpenCV/hands-on/runs/detect/day2result/predict

# %%
from PIL import Image
image=Image.open("runs/detect/day2result/predict/image1.jpg")
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x664>

# %%
model = YOLO("yolo11n.pt")
pathvideo1 = "../assets/day2/video1.mp4"
result = model.predict(source=pathvideo1,save=True,project="day2result")
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/458) /media/dani/WareHouseHDD1/GitHub/ComputerVision_Yolo_OpenCV/hands-on/../assets/day2/video1.mp4: 384x640 10 persons, 10 bicycles, 1 handbag, 3.5ms
# video 1/1 (frame 2/458) /media/dani/WareHouseHDD1/GitHub/ComputerVision_Yolo_OpenCV/hands-on/../assets/day2/video1.mp4: 384x640 10 persons, 9 bicycles, 4.2ms
# ...

# %%
url= "https://drive.usercontent.google.com/u/0/uc?id=1NODzqEA696P1wQX7XfDv6V58FP3ccy1a&export=download"
r=requests.get(url)
r.raise_for_status()

with open("../assets/day2/video2.mp4", "wb") as f:
    f.write(r.content)

# %%
model = YOLO("yolo11n.pt")
pathvideo2 = "../assets/day2/video2.mp4"

result = model.predict(source=pathvideo2, save=True,project="day2result")
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/519) /media/dani/WareHouseHDD1/GitHub/ComputerVision_Yolo_OpenCV/hands-on/../assets/day2/video2.mp4: 384x640 13 persons, 4.1ms
# video 1/1 (frame 2/519) /media/dani/WareHouseHDD1/GitHub/ComputerVision_Yolo_OpenCV/hands-on/../assets/day2/video2.mp4: 384x640 12 persons, 4.0ms
# ...
